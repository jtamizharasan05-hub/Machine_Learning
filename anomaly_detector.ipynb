# %%
import pandas as pd
import numpy as np
from google.colab import files
import warnings
warnings.filterwarnings("ignore")
uploaded = files.upload()
data = pd.read_csv("networkanomalydataset.csv")
print(data.head())
# Out:
#      <input type="file" id="files-e2796a44-5801-4577-906b-111c4d884d3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2796a44-5801-4577-906b-111c4d884d3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as py

print("shape of data", data.shape)
print("column names")
print(data.columns)
print("dataset info")
print(data.info())
print("null values:")
print(data.isnull().sum())
# Out:
# shape of data (1654, 5)
# column names
# Index(['Inbound Rate(bit/s)', 'Outbound Rate(bit/s)',
#        'Inbound Bandwidth Utilization(%)', 'Outbound Bandwidth Utilization(%)',
#        'Label'],
#       dtype='object')
# dataset info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1654 entries, 0 to 1653
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Inbound Rate(bit/s)                1654 non-null   float64
#  1   Outbound Rate(bit/s)               1654 non-null   float64
#  2   Inbound Bandwidth Utilization(%)   1654 non-null   float64
#  3   Outbound Bandwidth Utilization(%)  1654 non-null   float64
#  4   Label                              1654 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 64.7 KB
# None
# null values:
# Inbound Rate(bit/s)                  0
# Outbound Rate(bit/s)                 0
# ...

# %%
x = data.drop("Label", axis = 1)
y = data["Label"]
print(x.shape)
print(y.shape)
# Out:
# (1654, 4)
# (1654,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1323, 4)
# (1323,)
# (331, 4)
# (331,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test, y_pred)
print("Model accuracy", accuracy)
# Out:
# Model accuracy 0.945619335347432

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, y_pred)
print("confusion matrix")
print(cm)
# Out:
# confusion matrix
# [[161  18]
#  [  0 152]]

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95       179
#            1       0.89      1.00      0.94       152
#
#     accuracy                           0.95       331
#    macro avg       0.95      0.95      0.95       331
# weighted avg       0.95      0.95      0.95       331

# %%
inbound = float(input("inbound rate: "))
outbound = float(input("outbound rate: "))
in_util = float(input("inbound utilization: "))
out_util = float(input("outbound utilization: "))

manual_input = [[inbound, outbound, in_util, out_util]]
prediction = model.predict(manual_input)

if prediction[0] == 0:
  print("normal traffic")
else:
  print("anomaly detected")

model.predict_proba(manual_input)
print(model.coef_)
# Out:
# inbound rate: 1
# outbound rate: 2
# inbound utilization: 1
# outbound utilization: 2
# normal traffic
# [[-4.75559495 -3.05164138 -4.75706119 -3.05700003]]
